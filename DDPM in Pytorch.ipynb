# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulmr/ddpm-test-colab/blob/main/DDPM%20in%20Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Denoising Diffusion Probabilistic Models Implementation in Pytorch
# 1. Unzip the file
# 2. Go to Anaconda Command Promt
# 3. Go to the directory where the files have been unzipped
# 4. Run the Following commands:
# ```
# 	conda create --name myenv python=3.8
# 	conda activate newenv
# 	pip install -r requirements1.txt
# 	python utils/extract_mnist_images.py
# 	python -m tools.train_ddpm
# 	python -m tools.sample_ddpm
# ```

# %%
# !unzip /content/DDPM-Pytorch.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: data/train/images/9/19396.png
#  extracting: data/train/images/9/1940.png
#  extracting: data/train/images/9/19404.png
#  extracting: data/train/images/9/1941.png
#  extracting: data/train/images/9/19413.png
#  extracting: data/train/images/9/19418.png
#  extracting: data/train/images/9/19429.png
#  extracting: data/train/images/9/19438.png
#  extracting: data/train/images/9/19458.png
#  extracting: data/train/images/9/19478.png
#  extracting: data/train/images/9/19495.png
#  extracting: data/train/images/9/1950.png
#  extracting: data/train/images/9/1951.png
#  extracting: data/train/images/9/19513.png
#  extracting: data/train/images/9/19514.png
#  extracting: data/train/images/9/19516.png
#  extracting: data/train/images/9/19538.png
#  extracting: data/train/images/9/19540.png
#  extracting: data/train/images/9/19547.png
#  extracting: data/train/images/9/19559.png
#  extracting: data/train/images/9/19561.png
# ...
